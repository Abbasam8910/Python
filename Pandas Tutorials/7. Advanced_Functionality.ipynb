# %% [markdown]
# # Advanced Functionality
#
# - shift() rank() cumsum() rolling()

# %%
import pandas as pd
coffee = pd.read_csv("./Warmup Data/coffee.csv")
result = pd.read_parquet("./Data/results.parquet")
ympics_data=pd.read_excel("./Data/olympics-data.xlsx", sheet_name="results")
bios=pd.read_csv("./Data/bios.csv")

# %%
latte = coffee[coffee['Coffee Type']=="Latte"].copy()
latte['3day'] = latte['Units Sold'].rolling(3).sum()

# %%
latte
# Out:
#           Day Coffee Type  Units Sold   3day
# 1      Monday       Latte          15    NaN
# 3     Tuesday       Latte          20    NaN
# 5   Wednesday       Latte          25   60.0
# 7    Thursday       Latte          30   75.0
# 9      Friday       Latte          35   90.0
# 11   Saturday       Latte          35  100.0
# 13     Sunday       Latte          35  105.0

# %%
# !pip install pyjanitor
# Out:
# Requirement already satisfied: pyjanitor in d:\cusat\python\.venv\lib\site-packages (0.31.0)
# Requirement already satisfied: natsort in d:\cusat\python\.venv\lib\site-packages (from pyjanitor) (8.4.0)
# Requirement already satisfied: pandas_flavor in d:\cusat\python\.venv\lib\site-packages (from pyjanitor) (0.7.0)
# Requirement already satisfied: multipledispatch in d:\cusat\python\.venv\lib\site-packages (from pyjanitor) (1.0.0)
# Requirement already satisfied: scipy in d:\cusat\python\.venv\lib\site-packages (from pyjanitor) (1.15.3)
# Requirement already satisfied: pandas>=0.23 in d:\cusat\python\.venv\lib\site-packages (from pandas_flavor->pyjanitor) (2.2.3)
# Requirement already satisfied: xarray in d:\cusat\python\.venv\lib\site-packages (from pandas_flavor->pyjanitor) (2025.4.0)
# Requirement already satisfied: numpy>=1.26.0 in d:\cusat\python\.venv\lib\site-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\cusat\python\.venv\lib\site-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\cusat\python\.venv\lib\site-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\cusat\python\.venv\lib\site-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\cusat\python\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_flavor->pyjanitor) (1.16.0)
# Requirement already satisfied: packaging>=23.2 in d:\cusat\python\.venv\lib\site-packages (from xarray->pandas_flavor->pyjanitor) (24.1)

# %%
import janitor

coffee.clean_names()
# Out:
#           day coffee_type  units_sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# !pip install skimpy
# Out:
# Collecting skimpy
#   Downloading skimpy-0.0.18-py3-none-any.whl.metadata (34 kB)
# Collecting click>=8.1.7 (from skimpy)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: ipykernel>=6.29.5 in d:\cusat\python\.venv\lib\site-packages (from skimpy) (6.29.5)
# Requirement already satisfied: numpy>=2.0.2 in d:\cusat\python\.venv\lib\site-packages (from skimpy) (2.1.0)
# Collecting pandas-stubs>=2.2.2.240807 (from skimpy)
#   Downloading pandas_stubs-2.2.3.250527-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas>=2.2.3 in d:\cusat\python\.venv\lib\site-packages (from skimpy) (2.2.3)
# Collecting polars>=1.17.1 (from skimpy)
#   Downloading polars-1.30.0-cp39-abi3-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: pygments>=2.18.0 in d:\cusat\python\.venv\lib\site-packages (from skimpy) (2.18.0)
# Collecting rich>=13.9.4 (from skimpy)
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting typeguard>=4.4.1 (from skimpy)
#   Downloading typeguard-4.4.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pyarrow>=17.0.0 in d:\cusat\python\.venv\lib\site-packages (from skimpy) (20.0.0)
# Requirement already satisfied: colorama in d:\cusat\python\.venv\lib\site-packages (from click>=8.1.7->skimpy) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (8.26.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (0.1.7)
# Requirement already satisfied: nest-asyncio in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (1.6.0)
# Requirement already satisfied: packaging in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (24.1)
# Requirement already satisfied: psutil in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (26.1.0)
# Requirement already satisfied: tornado>=6.1 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in d:\cusat\python\.venv\lib\site-packages (from ipykernel>=6.29.5->skimpy) (5.14.3)
# Requirement already satisfied: decorator in d:\cusat\python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\cusat\python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\cusat\python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (3.0.47)
# Requirement already satisfied: stack-data in d:\cusat\python\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.6.3)
# Requirement already satisfied: wcwidth in d:\cusat\python\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\cusat\python\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\cusat\python\.venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.29.5->skimpy) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in d:\cusat\python\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->skimpy) (4.2.2)
# Requirement already satisfied: pywin32>=300 in d:\cusat\python\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->skimpy) (306)
# Requirement already satisfied: pytz>=2020.1 in d:\cusat\python\.venv\lib\site-packages (from pandas>=2.2.3->skimpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\cusat\python\.venv\lib\site-packages (from pandas>=2.2.3->skimpy) (2025.2)
# Collecting types-pytz>=2022.1.1 (from pandas-stubs>=2.2.2.240807->skimpy)
#   Downloading types_pytz-2025.2.0.20250516-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: six>=1.5 in d:\cusat\python\.venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=6.29.5->skimpy) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.9.4->skimpy)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.9.4->skimpy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting typing_extensions>=4.14.0 (from typeguard>=4.4.1->skimpy)
#   Using cached typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: executing>=1.2.0 in d:\cusat\python\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\cusat\python\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (2.4.1)
# Requirement already satisfied: pure-eval in d:\cusat\python\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.3)
# Downloading skimpy-0.0.18-py3-none-any.whl (17 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Downloading pandas_stubs-2.2.3.250527-py3-none-any.whl (159 kB)
# Downloading polars-1.30.0-cp39-abi3-win_amd64.whl (36.4 MB)
#    ---------------------------------------- 0.0/36.4 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.4 MB 7.2 MB/s eta 0:00:05
#    -- ------------------------------------- 2.1/36.4 MB 5.6 MB/s eta 0:00:07
#    -- ------------------------------------- 2.6/36.4 MB 4.3 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/36.4 MB 4.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.7/36.4 MB 3.8 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.2/36.4 MB 3.3 MB/s eta 0:00:10
#    ----- ---------------------------------- 4.7/36.4 MB 3.1 MB/s eta 0:00:11
#    ----- ---------------------------------- 5.0/36.4 MB 2.9 MB/s eta 0:00:11
#    ------ --------------------------------- 5.5/36.4 MB 2.9 MB/s eta 0:00:11
#    ------ --------------------------------- 6.0/36.4 MB 2.8 MB/s eta 0:00:11
#    ------- -------------------------------- 6.6/36.4 MB 2.9 MB/s eta 0:00:11
#    ------- -------------------------------- 7.1/36.4 MB 2.9 MB/s eta 0:00:11
#    -------- ------------------------------- 7.6/36.4 MB 2.8 MB/s eta 0:00:11
#    -------- ------------------------------- 8.1/36.4 MB 2.8 MB/s eta 0:00:11
#    --------- ------------------------------ 8.7/36.4 MB 2.7 MB/s eta 0:00:11
#    ---------- ----------------------------- 9.2/36.4 MB 2.7 MB/s eta 0:00:11
#    ---------- ----------------------------- 9.7/36.4 MB 2.7 MB/s eta 0:00:10
#    ----------- ---------------------------- 10.2/36.4 MB 2.7 MB/s eta 0:00:10
#    ----------- ---------------------------- 10.7/36.4 MB 2.7 MB/s eta 0:00:10
#    ------------ --------------------------- 11.3/36.4 MB 2.7 MB/s eta 0:00:10
#    ------------ --------------------------- 11.8/36.4 MB 2.7 MB/s eta 0:00:10
#    ------------- -------------------------- 12.3/36.4 MB 2.7 MB/s eta 0:00:10
#    -------------- ------------------------- 12.8/36.4 MB 2.6 MB/s eta 0:00:09
#    -------------- ------------------------- 13.4/36.4 MB 2.6 MB/s eta 0:00:09
#    --------------- ------------------------ 14.2/36.4 MB 2.7 MB/s eta 0:00:09
#    --------------- ------------------------ 14.4/36.4 MB 2.6 MB/s eta 0:00:09
#    ---------------- ----------------------- 14.9/36.4 MB 2.6 MB/s eta 0:00:09
#    ----------------- ---------------------- 15.5/36.4 MB 2.6 MB/s eta 0:00:09
#    ----------------- ---------------------- 16.0/36.4 MB 2.6 MB/s eta 0:00:08
#    ------------------ --------------------- 16.5/36.4 MB 2.6 MB/s eta 0:00:08
#    ------------------ --------------------- 17.0/36.4 MB 2.6 MB/s eta 0:00:08
#    ------------------- -------------------- 17.6/36.4 MB 2.6 MB/s eta 0:00:08
#    ------------------- -------------------- 18.1/36.4 MB 2.6 MB/s eta 0:00:08
#    -------------------- ------------------- 18.6/36.4 MB 2.6 MB/s eta 0:00:07
#    --------------------- ------------------ 19.1/36.4 MB 2.6 MB/s eta 0:00:07
#    --------------------- ------------------ 19.7/36.4 MB 2.6 MB/s eta 0:00:07
#    --------------------- ------------------ 19.9/36.4 MB 2.6 MB/s eta 0:00:07
#    ---------------------- ----------------- 20.4/36.4 MB 2.5 MB/s eta 0:00:07
#    ---------------------- ----------------- 20.7/36.4 MB 2.5 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.2/36.4 MB 2.5 MB/s eta 0:00:07
#    ----------------------- ---------------- 21.8/36.4 MB 2.5 MB/s eta 0:00:06
#    ------------------------ --------------- 22.3/36.4 MB 2.5 MB/s eta 0:00:06
#    ------------------------- -------------- 23.1/36.4 MB 2.5 MB/s eta 0:00:06
#    ------------------------- -------------- 23.6/36.4 MB 2.5 MB/s eta 0:00:06
#    -------------------------- ------------- 24.1/36.4 MB 2.5 MB/s eta 0:00:05
#    --------------------------- ------------ 24.6/36.4 MB 2.5 MB/s eta 0:00:05
#    --------------------------- ------------ 25.2/36.4 MB 2.5 MB/s eta 0:00:05
#    --------------------------- ------------ 25.4/36.4 MB 2.5 MB/s eta 0:00:05
#    ---------------------------- ----------- 25.7/36.4 MB 2.5 MB/s eta 0:00:05
#    ---------------------------- ----------- 26.2/36.4 MB 2.5 MB/s eta 0:00:05
#    ----------------------------- ---------- 26.5/36.4 MB 2.5 MB/s eta 0:00:05
#    ----------------------------- ---------- 27.0/36.4 MB 2.5 MB/s eta 0:00:04
#    ------------------------------ --------- 27.5/36.4 MB 2.5 MB/s eta 0:00:04
#    ------------------------------ --------- 28.0/36.4 MB 2.5 MB/s eta 0:00:04
#    ------------------------------- -------- 28.6/36.4 MB 2.5 MB/s eta 0:00:04
#    -------------------------------- ------- 29.4/36.4 MB 2.5 MB/s eta 0:00:03
#    -------------------------------- ------- 29.6/36.4 MB 2.5 MB/s eta 0:00:03
#    --------------------------------- ------ 30.1/36.4 MB 2.5 MB/s eta 0:00:03
#    --------------------------------- ------ 30.4/36.4 MB 2.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 30.9/36.4 MB 2.4 MB/s eta 0:00:03
#    ---------------------------------- ----- 31.5/36.4 MB 2.4 MB/s eta 0:00:03
#    ----------------------------------- ---- 32.0/36.4 MB 2.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.5/36.4 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------ --- 33.0/36.4 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------ --- 33.3/36.4 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------- -- 33.8/36.4 MB 2.4 MB/s eta 0:00:02
#    ------------------------------------- -- 34.3/36.4 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 34.9/36.4 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 36.4/36.4 MB 2.3 MB/s eta 0:00:00
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading typeguard-4.4.3-py3-none-any.whl (34 kB)
# Downloading types_pytz-2025.2.0.20250516-py3-none-any.whl (10 kB)
# Using cached typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Installing collected packages: typing_extensions, types-pytz, polars, mdurl, click, typeguard, pandas-stubs, markdown-it-py, rich, skimpy
#
#    ----------------------------------------  0/10 [typing_extensions]
#    ----------------------------------------  0/10 [typing_extensions]
#    ---- -----------------------------------  1/10 [types-pytz]
#    ---- -----------------------------------  1/10 [types-pytz]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    -------- -------------------------------  2/10 [polars]
#    ------------ ---------------------------  3/10 [mdurl]
#    ------------ ---------------------------  3/10 [mdurl]
#    ---------------- -----------------------  4/10 [click]
#    ---------------- -----------------------  4/10 [click]
#    ---------------- -----------------------  4/10 [click]
#    ---------------- -----------------------  4/10 [click]
#    -------------------- -------------------  5/10 [typeguard]
#    -------------------- -------------------  5/10 [typeguard]
#    -------------------- -------------------  5/10 [typeguard]
#    ------------------------ ---------------  6/10 [pandas-stubs]
#    ------------------------ ---------------  6/10 [pandas-stubs]
#    ------------------------ ---------------  6/10 [pandas-stubs]
#    ------------------------ ---------------  6/10 [pandas-stubs]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    ---------------------------- -----------  7/10 [markdown-it-py]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    -------------------------------- -------  8/10 [rich]
#    ------------------------------------ ---  9/10 [skimpy]
#    ------------------------------------ ---  9/10 [skimpy]
#    ---------------------------------------- 10/10 [skimpy]
#
# Successfully installed click-8.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 pandas-stubs-2.2.3.250527 polars-1.30.0 rich-14.0.0 skimpy-0.0.18 typeguard-4.4.3 types-pytz-2025.2.0.20250516 typing_extensions-4.14.0

# %%
from skimpy import skim

skim(result)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 308408 │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 11     │ │ float64     │ 2     │                                                          │
# │ └───────────────────┴────────┘ │ int64       │ 1     │                                                          │
# │                                │ bool        │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column      ┃ NA    ┃ NA %               ┃ mean  ┃ sd    ┃ p0   ┃ p25   ┃ p50   ┃ p75    ┃ p100   ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━┩  │
# │ │ year        │  2601 │ 0.8433633368784208 │  1982 │ 30.98 │ 1896 │  1964 │  1992 │   2008 │   2022 │ ▁▂▂▅▇▇ │  │
# │ │ athlete_id  │     0 │                  0 │ 72620 │ 41290 │    1 │ 34410 │ 73740 │ 107200 │ 149000 │ ▆▇▆▇▇▅ │  │
# │ │ place       │ 25215 │   8.17585795439807 │  16.1 │ 19.32 │    1 │     5 │     9 │     20 │    185 │   ▇▁   │  │
# │ └─────────────┴───────┴────────────────────┴───────┴───────┴──────┴───────┴───────┴────────┴────────┴────────┘  │
# │                                                      bool                                                       │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column                  ┃ true                 ┃ true rate                        ┃ hist                   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ tied                    │                45940 │                             0.15 │         ▇    ▁         │  │
# │ └─────────────────────────┴──────────────────────┴──────────────────────────────────┴────────────────────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┓  │
# │ ┃          ┃        ┃          ┃          ┃          ┃          ┃          ┃ chars    ┃ words    ┃ total     ┃  │
# │ ┃ column   ┃ NA     ┃ NA %     ┃ shortest ┃ longest  ┃ min      ┃ max      ┃ per row  ┃ per row  ┃ words     ┃  │
# │ ┡━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━┩  │
# │ │ type     │   2601 │ 0.843363 │ Summer   │ Summer   │ Summer   │ Winter   │        6 │     0.99 │    305807 │  │
# │ │          │        │ 33687842 │          │          │          │          │          │          │           │  │
# │ │          │        │       08 │          │          │          │          │          │          │           │  │
# │ │ discipli │      1 │ 0.000324 │ Golf     │ Short    │ 3-on-3   │ Wrestlin │     16.7 │        2 │    610211 │  │
# │ │ ne       │        │ 24580425 │          │ Track    │ Ice      │ g        │          │          │           │  │
# │ │          │        │   929287 │          │ Speed    │ Hockey   │          │          │          │           │  │
# │ │          │        │          │          │ Skating  │ (Ice     │          │          │          │           │  │
# │ │          │        │          │          │ (Skating │ Hockey)  │          │          │          │           │  │
# │ │          │        │          │          │ )        │          │          │          │          │           │  │
# │ │ event    │      0 │        0 │ Polo     │ 26th     │ 0-½ Ton, │ ≤85      │     30.1 │      4.2 │   1303323 │  │
# │ │          │        │          │          │ Federal  │ Open     │ kilogram │          │          │           │  │
# │ │          │        │          │          │ Festival │ (Olympic │ s, Greco │          │          │           │  │
# │ │          │        │          │          │ ,        │ )        │ Roman,   │          │          │           │  │
# │ │          │        │          │          │ Society  │          │ Boys     │          │          │           │  │
# │ │          │        │          │          │ and      │          │ (YOG)    │          │          │           │  │
# │ │          │        │          │          │ Associat │          │          │          │          │           │  │
# │ │          │        │          │          │ ion      │          │          │          │          │           │  │
# │ │          │        │          │          │ Contests │          │          │          │          │           │  │
# │ │          │        │          │          │ ,        │          │          │          │          │           │  │
# │ │          │        │          │          │ Non-Simu │          │          │          │          │           │  │
# │ │          │        │          │          │ ltaneous │          │          │          │          │           │  │
# │ │          │        │          │          │ ,        │          │          │          │          │           │  │
# │ │          │        │          │          │ Shooting │          │          │          │          │           │  │
# │ │          │        │          │          │ Champion │          │          │          │          │           │  │
# │ │          │        │          │          │ ships,   │          │          │          │          │           │  │
# │ │          │        │          │          │ Honorary │          │          │          │          │           │  │
# │ │          │        │          │          │ Members  │          │          │          │          │           │  │
# │ │          │        │          │          │ and      │          │          │          │          │           │  │
# │ │          │        │          │          │ Associat │          │          │          │          │           │  │
# │ │          │        │          │          │ es, Men  │          │          │          │          │           │  │
# │ │          │        │          │          │ (Olympic │          │          │          │          │           │  │
# │ │          │        │          │          │ (non-med │          │          │          │          │           │  │
# │ │          │        │          │          │ al))     │          │          │          │          │           │  │
# │ │ as       │      0 │        0 │ SB       │ Georges, │ A J Kitt │ Аlex     │       14 │      2.1 │    634574 │  │
# │ │          │        │          │          │ Marquis  │          │ Halcheni │          │          │           │  │
# │ │          │        │          │          │ de       │          │ uk       │          │          │           │  │
# │ │          │        │          │          │ Créqui-M │          │          │          │          │           │  │
# │ │          │        │          │          │ ontfort  │          │          │          │          │           │  │
# │ │          │        │          │          │ de       │          │          │          │          │           │  │
# │ │          │        │          │          │ Courtivr │          │          │          │          │           │  │
# │ │          │        │          │          │ on       │          │          │          │          │           │  │
# │ │ noc      │      1 │ 0.000324 │ FRA      │ FRA      │ AFG      │ ZIM      │        3 │        1 │    308407 │  │
# │ │          │        │ 24580425 │          │          │          │          │          │          │           │  │
# │ │          │        │   929287 │          │          │          │          │          │          │           │  │
# │ │ team     │ 186694 │ 60.53474 │ C        │ Victoria │ 't       │ Ștefan   │     10.2 │     0.62 │    190405 │  │
# │ │          │        │ 61803844 │          │ n        │ Soulaiky │ Vasile   │          │          │           │  │
# │ │          │        │       24 │          │ Football │          │          │          │          │           │  │
# │ │          │        │          │          │ League/V │          │          │          │          │           │  │
# │ │          │        │          │          │ ictorian │          │          │          │          │           │  │
# │ │          │        │          │          │          │          │          │          │          │           │  │
# │ │          │        │          │          │ Football │          │          │          │          │           │  │
# │ │          │        │          │          │ Associat │          │          │          │          │           │  │
# │ │          │        │          │          │ ion      │          │          │          │          │           │  │
# │ │ medal    │ 264269 │ 85.68811 │ Gold     │ Bronze   │ Bronze   │ Silver   │     5.33 │     0.14 │     44139 │  │
# │ │          │        │ 44457990 │          │          │          │          │          │          │           │  │
# │ │          │        │        7 │          │          │          │          │          │          │           │  │
# │ └──────────┴────────┴──────────┴──────────┴──────────┴──────────┴──────────┴──────────┴──────────┴───────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %% [markdown]
# # New functionality

# %%
results_numpy = pd.read_csv('./data/results.csv')
results_arrow = pd.read_csv('./data/results.csv', engine='pyarrow', dtype_backend='pyarrow')

# %%
results_numpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
results_arrow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  double[pyarrow]
#  1   type        305807 non-null  string[pyarrow]
#  2   discipline  308407 non-null  string[pyarrow]
#  3   event       308408 non-null  string[pyarrow]
#  4   as          308408 non-null  string[pyarrow]
#  5   athlete_id  308408 non-null  int64[pyarrow]
#  6   noc         308407 non-null  string[pyarrow]
#  7   team        121714 non-null  string[pyarrow]
#  8   place       283193 non-null  double[pyarrow]
#  9   tied        308408 non-null  bool[pyarrow]
#  10  medal       44139 non-null   string[pyarrow]
# dtypes: bool[pyarrow](1), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](7)
# memory usage: 37.5 MB

# %%
filtered_bios = bios[(bios['born_region'] == 'New Hampshire') | (bios['born_city'] == 'San Francisco')]

bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
import pandas as pd

# Creating a DataFrame
data = {
    'Date': ['2024-05-01', '2024-05-01', '2024-05-01', '2024-05-02', '2024-05-02', '2024-05-03', '2024-05-03', '2024-05-03'],
    'Item': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Orange', 'Apple', 'Orange'],
    'Units Sold': [30, 21, 15, 40, 34, 20, 45, 25],
    'Price Per Unit': [1.0, 0.5, 0.75, 1.0, 0.5, 0.75, 1.0, 0.75],
    'Salesperson': ['John', 'John', 'John', 'Alice', 'Alice', 'John', 'Alice', 'John']
}

df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#          Date    Item  Units Sold  Price Per Unit Salesperson
# 0  2024-05-01   Apple          30            1.00        John
# 1  2024-05-01  Banana          21            0.50        John
# 2  2024-05-01  Orange          15            0.75        John
# 3  2024-05-02   Apple          40            1.00       Alice
# 4  2024-05-02  Banana          34            0.50       Alice
# 5  2024-05-03  Orange          20            0.75        John
# 6  2024-05-03   Apple          45            1.00       Alice
# 7  2024-05-03  Orange          25            0.75        John

# %%
pivot_table = pd.pivot_table(df, values='Units Sold', index='Date', columns='Item', aggfunc='sum')
pivot_table
# Out:
# Item        Apple  Banana  Orange
# Date
# 2024-05-01   30.0    21.0    15.0
# 2024-05-02   40.0    34.0     NaN
# 2024-05-03   45.0     NaN    45.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'bios' and already loaded
# First, filter out rows where the height_cm data is missing
bios_filtered = bios.dropna(subset=['height_cm'])

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(bios_filtered['height_cm'], bins=20, color='blue', edgecolor='black')

plt.title('Distribution of Athlete Heights in Olympics')
plt.xlabel('Height in cm')
plt.ylabel('Number of Athletes')
plt.grid(True)

# Using a logarithmic scale for the y-axis if the data spread is wide
plt.yscale('log')

plt.show()

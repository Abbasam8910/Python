# %% [markdown]
# Accessing Data with Pandas

# %%
import pandas as pd

# %%
# lets read all data files

coffe = pd.read_csv("./Warmup Data/coffee.csv")
result = pd.read_parquet("./Data/results.parquet")
ympics_data=pd.read_excel("./Data/olympics-data.xlsx", sheet_name="results")
bios=pd.read_csv("./Data/bios.csv")

# %%
print(coffe)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
display(coffe)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffe.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffe.tail(10)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffe.sample(10)  # To get random datas
# Out:
#           Day Coffee Type  Units Sold
# 7    Thursday       Latte          30
# 11   Saturday       Latte          35
# 0      Monday    Espresso          25
# 13     Sunday       Latte          35
# 10   Saturday    Espresso          45
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 4   Wednesday    Espresso          35
# 12     Sunday    Espresso          45
# 3     Tuesday       Latte          20

# %% [markdown]
# To Access specific value we use loc and iloc

# %%
# Loc
# coffe.loc[Rows, Coloumn]

coffe.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffe.loc[[0,1,5]]  # To print 1st,2nd and 6th rows
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffe.loc[1:3]
# Out:
#        Day Coffee Type  Units Sold
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffe.loc[1:5, ["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25

# %% [markdown]
# iloc

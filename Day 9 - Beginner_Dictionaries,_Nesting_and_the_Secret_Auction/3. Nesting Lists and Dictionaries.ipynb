# %% [markdown]
# # Nesting Lists and Dictionaries

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Nesting a List Inside a Dictionary

# %%
capitals={
    "France": "paris",
    "Germany": "Berlin"
}
print(capitals)
# Nested Dictionary

travel_log={
    "France":["paris","Lille","Dijon"],
    "Germany":["Berlin"]
}

print(travel_log)


# printing Lille 


print(travel_log["France"][1])
# Out:
# {'France': 'paris', 'Germany': 'Berlin'}
# {'France': ['paris', 'Lille', 'Dijon'], 'Germany': ['Berlin']}
# Lille

# %%
nested_list=["A","B",["C","D"]]

# Printing Letter "D"

print(nested_list[2][1])
# Out:
# D

# %% [markdown]
# Nesting a Dictionary Inside a Dictionary

# %%
travel_log={
    "France":{
        "Num_of_Time_visited":8,
        "Cities_visited":["Paris", "Lille","Dijon"]
    },   # Don;t miss comma here

    "Germany":{
        "Num_of_Time_visited":3,
        "Cities_visited":["Berlin", "Hamburg","Stuttgart"]
    }
}


print(travel_log)


# How to print Stuttgart 


print(travel_log["Germany"]["Cities_visited"][2])
# Out:
# {'France': {'Num_of_Time_visited': 8, 'Cities_visited': ['Paris', 'Lille', 'Dijon']}, 'Germany': {'Num_of_Time_visited': 3, 'Cities_visited': ['Berlin', 'Hamburg', 'Stuttgart']}}
# Stuttgart

# %%
order = {
    "starter": {1: "Salad", 2: "Soup"},
    "main": {1: ["Burger", "Fries"], 2: ["Steak"]},
    "dessert": {1: ["Ice Cream"], 2: []},
}

print(order["main"][2][0])
# Out:
# Steak

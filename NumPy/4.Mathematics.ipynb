# %% [markdown]
# Mathematics

# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
print(a+2)
# Out:
# [3 4 5 6 7]

# %%
print(a-2)
# Out:
# [-1  0  1  2  3]

# %%
print(a*2)
# Out:
# [ 2  4  6  8 10]

# %%
print(a/2)
# Out:
# [0.5 1.  1.5 2.  2.5]

# %%
b = np.array([4,5,7,9,6])
print(b)
# Out:
# [4 5 7 9 6]

# %%
print(a+b)
# Out:
# [ 5  7 10 13 11]

# %%
print(a**2)
# Out:
# [ 1  4  9 16 25]

# %%
# Take the sin


print(np.sin(a))
print(np.cos(a))
# Out:
# [ 0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427]
# [ 0.54030231 -0.41614684 -0.9899925  -0.65364362  0.28366219]

# %% [markdown]
# Mathematics

# %%
a=np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Mathematics
#
# NameError: name 'Mathematics' is not defined

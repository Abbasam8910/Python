# %% [markdown]
# # Day 11 Project: Blackjack Capstone Project

# %%
def reverse_string(s):
    return s[::-1]

# Example usage
example_string = "Blackjack"
reversed_string = reverse_string(example_string)
print(reversed_string)
# Out:
# kcajkcalB

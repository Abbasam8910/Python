# %% [markdown]
# # Functions with Outputs

# %% [markdown]
# Already Completed:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Function With Output
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Converting a String to a Title Case

# %%
def format_name(f_name, l_name):
    print(f_name.title(),l_name.title())
f_name="SaM"
l_name="WrEcK"

format_name(f_name,l_name)
# Out:
# SaM WrEcK

# %%
# Lets Return the Function

def format_name(f_name, l_name):
    # return f"{f_name.title()} {l_name.title()}"    OR

    formatted_fname=f_name.title()
    formatted_lname=l_name.title()

    return f"{formatted_fname} {formatted_lname}"
f_name="SaM"
l_name="WrEcK"

result = format_name(f_name,l_name)
print(result)
# Out:
# Sam Wreck

# %% [markdown]
# Output of a function as input of another function

# %%
def function1(text):
    return text + text

def function2(text):
    return text.title()


output = function2(function1("helo"))  # Output of function1 will become the input of function2

print(output)
# Out:
# Helohelo

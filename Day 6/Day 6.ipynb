# %% [markdown]
# # Python Function

# %%
def my_function():   # Defining Function
    print("Hello")
    print("Hey")

my_function()  # Calling Function
# Out:
# Hello
# Hey

# %% [markdown]
# # Function Calling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Indentation

# %% [markdown]
# ![image.png](attachment:image.png)

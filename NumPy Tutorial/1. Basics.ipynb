# %% [markdown]
#  Load in numpy

# %%
import numpy as np

# %% [markdown]
# The Basics

# %%
a=np.array([1,2,3])   # 1D array
print(a)
# Out:
# [1 2 3]

# %%
b=np.array([[9.0,8.0,7.0],[6.0,5.0,4.0]])   # 2D Array
print(b)
# Out:
# [[9. 8. 7.]
#  [6. 5. 4.]]

# %%
# Get the dimension
a.ndim
# Out:
# 1

# %%
# Get Shape

a.shape
# Out:
# (3,)

# %%
b.shape   # print 2 rows and 3 cols
# Out:
# (2, 3)

# %%
# get the type

a.dtype
# Out:
# dtype('int64')

# %%
d=np.array([1,2,3], dtype='int16')

d.dtype
# Out:
# dtype('int16')

# %%
#Get size
c=np.array([1,2,3], dtype='int32')  # 4 bytes

c.itemsize
# Out:
# 4

# %%
# Get total size

a.nbytes
# Out:
# 6

# %% [markdown]
# Statistics

# %%
import numpy as np

# %%
a=np.array([[2,3],[5,6]])
print(a)
# Out:
# [[2 3]
#  [5 6]]

# %%
print(np.min(a))
# Out:
# 2

# %%
print(np.max(a, axis=1))
# Out:
# [3 6]

# %%
print(np.sum(a, axis=0))
# Out:
# [7 9]

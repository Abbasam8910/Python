# %% [markdown]
# # Day 9 Project : The Secret Auction Program

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("\n Welcome to The Secret Auction Program")

gavel_ascii_art = r"""
 ___________
 \         /
  )_______(
  |"""""""|_.-._,.---------.,_.-._
  |       | | |               | | ''-.
  |       |_| |_             _| |_..-'
  |_______| '-' `'---------'` '-'
  )"""""""(
 /_________\
 `'-------'`
.-------------.
______________\
"""
print(gavel_ascii_art)

bid_continue=True

auction_bidders={}


while bid_continue:
    name=input("What is Your Name: \n")
    bid=int(input("What's Your Bid?: ₹ \n"))

    auction_bidders[name]=bid
    bidders=input("Any Other Users Wants to Bid : Type 'Yes' OR 'No'").lower()

    if bidders=="yes":
        print("\n"*3)
    else:
        bid_continue=False

        for values in auction_bidders:
            big_bid=0

            if auction_bidders[values]>big_bid:
                big_bid=auction_bidders[values]
        
        for values in auction_bidders:
            if big_bid==auction_bidders[values]:
                winner_name=values
                print(f"The Highest Big is {big_bid} and the Winner is {values}")

            
print(f"Congratulation {winner_name}")
# Out:
#  Welcome to The Secret Auction Program
#
#  ___________
#  \         /
#   )_______(
#   |"|_.-._,.---------.,_.-._
#   |       | | |               | | ''-.
#   |       |_| |_             _| |_..-'
#   |_______| '-' `'---------'` '-'
#   )"(
#  /_________ `'-------'`
# .-------------.
# ______________
#
#
#
#
#
#
#
#
# The Highest Big is 89000 and the Winner is rahul
# Congratulation rahul

# %% [markdown]
# # Python Function

# %%
def my_function():   # Defining Function
    print("Hello")
    print("Hey")

my_function()  # Calling Function
# Out:
# Hello
# Hey

# %% [markdown]
# # Function Calling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Indentation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can use Tab space or Space button to get proper indentation.
# - use one tab
#      or
# - use 4 space button or 2 space button

# %% [markdown]
# # While Loops

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Hurdle Challenge Using While Loop

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Jumping over Hurdles with Variable Heights

# %%
def jump():
    turn_left()
    turn_left()
    turn_left()
    move()
    turn_left()
    turn_left()
    turn_left()
    move()
    

while not at_goal():
    while front_is_clear():
        if front_is_clear() and right_is_clear():
            jump()
        
        else:
            if at_goal()==True:
                break
            else:
                move()
    if not front_is_clear():
        if not front_is_clear() and right_is_clear() and wall_on_right()==False:
            jump()
        else:
            turn_left()

# %% [markdown]
# ![image.png](attachment:image.png)
